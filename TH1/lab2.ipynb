# %% [markdown]
# W2A1

# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %% [markdown]
# W2A2

# %%
s=input()
print("Xin chao",s)
# Out:
# Xin chao 34

# %% [markdown]
# W2A3

# %%
a,b=map(int,input().split())
print(f"Tong cua {a} va {b} la: {a} + {b}= {a+b}")
print(f"Hieu cua {a} va {b} la: {a} - {b}= {a-b}")
print(f"Tich cua {a} va {b} la: {a} x {b}= {a*b}")
print(f"Phan nguyen cua {a} va {b} la: {a} // {b}= {a//b} ")
print(f"Phan du cua {a} va {b} la: {a} % {b}= {a%b}")
print(f"Ket qua chia thuc cua {a} va {b} la: {a} : {b}= {a/b:.2f}")
# Out:
# Tong cua 2 va 3 la: 2 + 3= 5
# Hieu cua 2 va 3 la: 2 - 3= -1
# Tich cua 2 va 3 la: 2 x 3= 6
# Phan nguyen cua 2 va 3 la: 2 // 3= 0
# Phan du cua 2 va 3 la: 2 % 3= 2
# Ket qua chia thuc cua 2 va 3 la: 2 : 3= 0.67

# %% [markdown]
# W2A4

# %%
a,b,c,d,e,f=map(float,input().split())
tb=((a+b+c)+(d+e)*2+(f)*3)/10
print(f"{tb:.2f}")
# Out:
# 4.20

# %% [markdown]
# W2A5

# %%
a,b=map(int,input().split())
print(a**b)
# Out:
# 729

# %% [markdown]
# W2A6

# %%
x=input()
n=ord(x)
print(chr(n-32))
# Out:
# S

# %% [markdown]
# W2A7

# %%
A=((13**2)*3)+5
B=13**2*3+5
print(A,B)
# Out:
# 512 512

# %% [markdown]
# W2A8

# %%
x=int(input())
cd=1.8*x+32
print(f"{cd:.2f}")
# Out:
# 73.40

# %% [markdown]
# W2A9

# %%
x=float(input())
ans=x*1.4+10
print(f"{ans:.2f}")
# Out:
# 490.20

# %% [markdown]
# W2A10

# %%
a,b,c=input().split()
print(f"Hi {c}, {b} and {a}. ")
# Out:
# Hi la, ok and ij.

# %% [markdown]
# W2A11

# %%
h,m=map(int,input().split())
ans=h*1600+m*60
print(ans)
# Out:
# 21780

# %% [markdown]
# W2A12

# %%
n=int(input())
ans=n**2*6
print(ans)
# Out:
# 3174

# %% [markdown]
# W2A13

# %%
a,b=map(int,input().split())
print(a*b%10)
# Out:
# 2

# %% [markdown]
# W2A14

# %%
a,b=map(int,input().split())
a,b=b,a
print(a,b)
# Out:
# 31231 213

# %% [markdown]
# W2A15

# %%
n=int(input())
ans=6*n*(n-1)+1
print(ans)
# Out:
# 793

# %% [markdown]
# W2A16

# %%
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# W2A17

# %%
n=int(input())
for i in range(n):
    print("*"*(2*i+1))
# Out:
# *
# ***
# *****

# %% [markdown]
# W2A18

# %%
print("###  ###   ###   ####")
print(" #   #  #   #     # ")
print(" #   #  #   #     # ")
print(" #   #  #   #     # ")
print(" #   ###    #     # ")
# Out:
# ###  ###   ###   ####
#  #   #  #   #     #
#  #   #  #   #     #
#  #   #  #   #     #
#  #   ###    #     #

# %% [markdown]
# W2A19

# %%
print("Monday")
print("Tuesday")
print("Wednesday")
print("Thursday")
print("Friday")
print("Saturday")
print("Sunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# W2A20

# %%
print("January")
print("February")
print("March")
print("April")
print("May")
print("June")
print("July")
print("August")
print("September")
print("October")
print("November")
print("December")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# W2A21

# %%
for i in range(10):
    print("Hello World")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
